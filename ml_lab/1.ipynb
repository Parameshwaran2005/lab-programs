# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing(as_frame=True)
df = data.frame

numerical_features = df.select_dtypes(include='number')

plt.figure(figsize=(15,8))
for i,feature in enumerate(numerical_features):
    plt.subplot(3,3,i+1)
    sns.histplot(numerical_features[feature],kde=True,bins=30,color='blue')
    plt.title(f"Distribution of {feature}")
plt.tight_layout()
plt.show()

plt.figure(figsize=(15,8))
for i,feature in enumerate(numerical_features):
    plt.subplot(3,3,i+1)
    sns.boxplot(x=numerical_features[feature],color='orange')
    plt.title(f"Box plot of {feature}")
plt.tight_layout()
plt.show()

outliers_summary = {}
for feature in numerical_features:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR 
    upper_bound = Q3 + 1.5*IQR
    outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
    outliers_summary[feature] = len(outliers)
    print(f"{feature}: {len(outliers)} outliers")
# Out:
# MedInc: 681 outliers
# HouseAge: 0 outliers
# AveRooms: 511 outliers
# AveBedrms: 1424 outliers
# Population: 1196 outliers
# AveOccup: 711 outliers
# Latitude: 0 outliers
# Longitude: 0 outliers
# MedHouseVal: 1071 outliers

# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt

data = fetch_california_housing(as_frame=True)
df = data.frame

numerical_features = df.select_dtypes(include='number')

plt.figure(figsize=(15,8))
for i,feature in enumerate(numerical_features):
    plt.subplot(3,3,i+1)
    sns.histplot(df[feature],kde=True,bins=30,color='red')
    plt.title(f"Distribution of {feature}")
plt.tight_layout()
plt.show()

plt.figure(figsize=(15,8))
for i,feature in enumerate(numerical_features):
    plt.subplot(3,3,i+1)
    sns.boxplot(x=df[feature],color='orange')
    plt.title(f"boxplot of {feature}")
plt.tight_layout()
plt.show()

# Outliers
outliers_summary = {}
for feature in numerical_features:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR
    outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
    outliers_summary[feature] = len(outliers)
    print(f"{feature}: {len(outliers)} outliers")
# Out:
# MedInc: 681 outliers
# HouseAge: 0 outliers
# AveRooms: 511 outliers
# AveBedrms: 1424 outliers
# Population: 1196 outliers
# AveOccup: 711 outliers
# Latitude: 0 outliers
# Longitude: 0 outliers
# MedHouseVal: 1071 outliers
